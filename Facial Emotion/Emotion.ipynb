# %% [markdown]
# ## Detecting Facial Emotion

# %%
import cv2
import matplotlib.pyplot as plt

# %%
pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\adith\anaconda3\lib\site-packages (0.0.70)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (1.21.3)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (1.1.3)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (1.1.2)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (0.0.7)
# Requirement already satisfied: opencv-python>=3.4.4 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (4.5.5.62)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (4.2.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (2.7.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (2.7.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (4.50.2)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (0.1.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\adith\anaconda3\lib\site-packages (from deepface) (8.0.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\adith\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\adith\anaconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2020.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\adith\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\users\adith\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\adith\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\adith\anaconda3\lib\site-packages (from Flask>=1.1.2->deepface) (2.11.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\adith\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.9.3)
# Requirement already satisfied: requests[socks] in c:\users\adith\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (2.24.0)
# Requirement already satisfied: six in c:\users\adith\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (1.15.0)
# Requirement already satisfied: filelock in c:\users\adith\anaconda3\lib\site-packages (from gdown>=3.10.1->deepface) (3.0.12)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.35.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.19.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.7.4.3)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.23.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.43.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.11.2)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (12.0.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\adith\anaconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\adith\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.1.2->deepface) (1.1.1)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\adith\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\adith\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\adith\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adith\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\adith\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in c:\users\adith\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (2.3.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (50.3.1.post20201107)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\adith\anaconda3\lib\site-packages (from tensorboard~=2.6->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\adith\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (4.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\adith\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\adith\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\adith\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\adith\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (4.2.4)
# Requirement already satisfied: zipp>=0.5 in c:\users\adith\anaconda3\lib\site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\adith\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\adith\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow>=1.9.0->deepface) (0.4.8)

# %%
from deepface import DeepFace

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\adith\anaconda3\lib\site-packages (4.5.5.62)
# Requirement already satisfied: numpy>=1.17.3; python_version >= "3.8" in c:\users\adith\anaconda3\lib\site-packages (from opencv-contrib-python) (1.21.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
img=cv2.imread('sad.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.25it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 3.385840014915468,
#   'disgust': 0.0019950649052563195,
#   'fear': 57.73044320707836,
#   'happy': 0.0020080257519984584,
#   'sad': 31.367144747632114,
#   'surprise': 0.0004404556945986849,
#   'neutral': 7.512129993692636},
#  'dominant_emotion': 'fear',
#  'region': {'x': 51, 'y': 18, 'w': 157, 'h': 157},
#  'age': 24,
#  'gender': 'Man',
#  'race': {'asian': 0.3492162562906742,
#   'indian': 0.0036847141018370166,
#   'black': 0.0002655735670487047,
#   'white': 97.46427536010742,
#   'middle eastern': 0.47667743638157845,
#   'latino hispanic': 1.7058813944458961},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
face=cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
faces=face.detectMultiScale(gray,1.1,4)
for(x,y,w,h)in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),4)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
img2=cv2.imread('happy1.jpg')

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB))

# %%
predictions1=DeepFace.analyze(img2)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.42it/s]

# %%
predictions1
# Out:
# {'emotion': {'angry': 1.2548079553198477e-05,
#   'disgust': 5.781447889874336e-09,
#   'fear': 0.0002908261194534134,
#   'happy': 99.8029887676239,
#   'sad': 0.0001693569174676668,
#   'surprise': 8.120899224195455e-05,
#   'neutral': 0.19646272994577885},
#  'dominant_emotion': 'happy',
#  'region': {'x': 11, 'y': 100, 'w': 161, 'h': 161},
#  'age': 27,
#  'gender': 'Man',
#  'race': {'asian': 0.023435940849408907,
#   'indian': 0.07464362732543078,
#   'black': 0.000949826630399617,
#   'white': 82.531777922127,
#   'middle eastern': 11.759849549514001,
#   'latino hispanic': 5.609347222369578},
#  'dominant_race': 'white'}

# %%
img3=cv2.imread('suprise1.jpg')

# %%
plt.imshow(cv2.cvtColor(img3,cv2.COLOR_BGR2RGB))

# %%
predictions3=DeepFace.analyze(img3)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]

# %%
predictions3
# Out:
# {'emotion': {'angry': 0.02984512539114803,
#   'disgust': 1.3807600895976435e-09,
#   'fear': 0.0990438275039196,
#   'happy': 31.211289763450623,
#   'sad': 0.9598051197826862,
#   'surprise': 67.69993305206299,
#   'neutral': 8.319850621774094e-05},
#  'dominant_emotion': 'surprise',
#  'region': {'x': 91, 'y': 35, 'w': 64, 'h': 64},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 7.701191654486509e-06,
#   'indian': 1.6216723451581514e-05,
#   'black': 6.581545079278304e-08,
#   'white': 99.46784979488255,
#   'middle eastern': 0.1856899948154396,
#   'latino hispanic': 0.3464289062256925},
#  'dominant_race': 'white'}
